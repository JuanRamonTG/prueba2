# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanRamonTG/prueba2/blob/main/Introduccion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Mundo")
print("Bienvenidos chicos a programacion 3")
# Out:
# Hola Mundo
# Bienvenidos chicos a programacion 3

# %%
nombre = "Juan Ramon"
edad = 5
print(nombre, edad)

edad = "cinco"
print("Tu edad:", edad)
# Out:
# Juan Ramon 5
# Tu edad: cinco

# %%
num1 = 5
num2 = 8.9
suma = num1 + num2
print("La suma es: ", suma)
# Out:
# La suma es:  13.9

# %%
num1 = float(input("Num1: "))
num2 = float(input("Num2: "))
suma = num1 + num2
print("La suma es: ", suma)
# Out:
# Num1: 88
# Num2: 88
# La suma es:  176.0

# %%
num1 = float(input("Num1: "))
num2 = float(input("Num2: "))
resta = num1 - num2
print("La resta es: ", resta)
print("E: ", resta)
# Out:
# Num1: 5
# Num2: 5
# La resta es:  0.0
